# %% [markdown]
# <a href="https://colab.research.google.com/github/mayeedit3/ChamPub/blob/master/ChamT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import statsmodels.api as sm
#%matplotlib inline
df=pd.read_csv('https://raw.githubusercontent.com/mayeedit3/FREXCH/master/Foreign_Exchange_Rates.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Time Serie  ... TAIWAN - NEW TAIWAN DOLLAR/US$ THAILAND - BAHT/US$
# 0           0  2000-01-03  ...                          31.38               36.97
# 1           1  2000-01-04  ...                           30.6               37.13
# 2           2  2000-01-05  ...                           30.8                37.1
# 3           3  2000-01-06  ...                          31.75               37.62
# 4           4  2000-01-07  ...                          30.85                37.3
#
# [5 rows x 24 columns]

# %%
df1 = df[['Time Serie','AUSTRALIA - AUSTRALIAN DOLLAR/US$']]
df1.head(40)
# Out:
#     Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$
# 0   2000-01-03                            1.5172
# 1   2000-01-04                            1.5239
# 2   2000-01-05                            1.5267
# 3   2000-01-06                            1.5291
# 4   2000-01-07                            1.5272
# 5   2000-01-10                            1.5242
# 6   2000-01-11                            1.5209
# 7   2000-01-12                            1.5202
# 8   2000-01-13                            1.4954
# 9   2000-01-14                            1.5004
# 10  2000-01-17                                ND
# 11  2000-01-18                             1.506
# 12  2000-01-19                            1.5074
# 13  2000-01-20                            1.5002
# 14  2000-01-21                            1.5103
# 15  2000-01-24                            1.5281
# 16  2000-01-25                            1.5286
# 17  2000-01-26                            1.5373
# ...

# %%
df1[df1['AUSTRALIA - AUSTRALIAN DOLLAR/US$']!='ND'].head(40)
# Out:
#     Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$
# 0   2000-01-03                            1.5172
# 1   2000-01-04                            1.5239
# 2   2000-01-05                            1.5267
# 3   2000-01-06                            1.5291
# 4   2000-01-07                            1.5272
# 5   2000-01-10                            1.5242
# 6   2000-01-11                            1.5209
# 7   2000-01-12                            1.5202
# 8   2000-01-13                            1.4954
# 9   2000-01-14                            1.5004
# 11  2000-01-18                             1.506
# 12  2000-01-19                            1.5074
# 13  2000-01-20                            1.5002
# 14  2000-01-21                            1.5103
# 15  2000-01-24                            1.5281
# 16  2000-01-25                            1.5286
# 17  2000-01-26                            1.5373
# 18  2000-01-27                            1.5267
# ...

# %%
df1.dropna(axis=0, how='any', inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1.head(40)
# Out:
#     Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$
# 0   2000-01-03                            1.5172
# 1   2000-01-04                            1.5239
# 2   2000-01-05                            1.5267
# 3   2000-01-06                            1.5291
# 4   2000-01-07                            1.5272
# 5   2000-01-10                            1.5242
# 6   2000-01-11                            1.5209
# 7   2000-01-12                            1.5202
# 8   2000-01-13                            1.4954
# 9   2000-01-14                            1.5004
# 10  2000-01-17                                ND
# 11  2000-01-18                             1.506
# 12  2000-01-19                            1.5074
# 13  2000-01-20                            1.5002
# 14  2000-01-21                            1.5103
# 15  2000-01-24                            1.5281
# 16  2000-01-25                            1.5286
# 17  2000-01-26                            1.5373
# ...

# %%
df1.isnull().sum()
# Out:
# Time Serie                           0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$    0
# dtype: int64

# %%
df1['AUSTRALIA - AUSTRALIAN DOLLAR/US$'].replace('ND',0,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df2=df1['AUSTRALIA - AUSTRALIAN DOLLAR/US$'].drop(df1['AUSTRALIA - AUSTRALIAN DOLLAR/US$'][df1['AUSTRALIA - AUSTRALIAN DOLLAR/US$']==0])

# %%
df1
# Out:
#       Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$
# 0     2000-01-03                            1.5172
# 1     2000-01-04                            1.5239
# 2     2000-01-05                            1.5267
# 3     2000-01-06                            1.5291
# 4     2000-01-07                            1.5272
# ...          ...                               ...
# 5212  2019-12-25                                 0
# 5213  2019-12-26                            1.4411
# 5214  2019-12-27                            1.4331
# 5215  2019-12-30                            1.4278
# 5216  2019-12-31                            1.4225
#
# [5217 rows x 2 columns]

# %%
df2
# Out:
# 1       1.5239
# 2       1.5267
# 3       1.5291
# 4       1.5272
# 5       1.5242
#          ...
# 5212         0
# 5213    1.4411
# 5214    1.4331
# 5215    1.4278
# 5216    1.4225
# Name: AUSTRALIA - AUSTRALIAN DOLLAR/US$, Length: 5216, dtype: object

# %%
Other = df1['AUSTRALIA - AUSTRALIAN DOLLAR/US$'][df1['AUSTRALIA - AUSTRALIAN DOLLAR/US$']==0]
Other
# Out:
# 10      0
# 35      0
# 105     0
# 131     0
# 175     0
#        ..
# 5130    0
# 5160    0
# 5180    0
# 5193    0
# 5212    0
# Name: AUSTRALIA - AUSTRALIAN DOLLAR/US$, Length: 198, dtype: object

# %%
df1[df1['AUSTRALIA - AUSTRALIAN DOLLAR/US$']!=0].head(40)
# Out:
#     Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$
# 0   2000-01-03                            1.5172
# 1   2000-01-04                            1.5239
# 2   2000-01-05                            1.5267
# 3   2000-01-06                            1.5291
# 4   2000-01-07                            1.5272
# 5   2000-01-10                            1.5242
# 6   2000-01-11                            1.5209
# 7   2000-01-12                            1.5202
# 8   2000-01-13                            1.4954
# 9   2000-01-14                            1.5004
# 11  2000-01-18                             1.506
# 12  2000-01-19                            1.5074
# 13  2000-01-20                            1.5002
# 14  2000-01-21                            1.5103
# 15  2000-01-24                            1.5281
# 16  2000-01-25                            1.5286
# 17  2000-01-26                            1.5373
# 18  2000-01-27                            1.5267
# ...

# %%
plt.plot(df1)#["Time Serie"], df1["AUSTRALIA - AUSTRALIAN DOLLAR/US$"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-f3bde824474b> in <module>()
# ----> 1 plt.plot(df1)#["Time Serie"], df1["AUSTRALIA - AUSTRALIAN DOLLAR/US$"])
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...
